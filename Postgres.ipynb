# %%
# Import SQL Alchemy
from sqlalchemy import create_engine

# %%
# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd

# %%
DATABASE_URI = 'postgres+psycopg2://postgres:postgres@localhost/Pokemon'
engine = create_engine(DATABASE_URI)
data = pd.read_sql("SELECT * FROM poke_data", engine)
data
# Out:
#      poke_id   poke_name  poke_gen poke_type1 poke_type2 poke_ability1  \
# 0          1   Bulbasaur         1      grass     poison      Overgrow
# 1          2     Ivysaur         1      grass     poison      Overgrow
# 2          3    Venusaur         1      grass     poison      Overgrow
# 3          4  Charmander         1       fire          -         Blaze
# 4          5  Charmeleon         1       fire          -         Blaze
# ..       ...         ...       ...        ...        ...           ...
# 796      797  Celesteela         7      steel     flying   Beast Boost
# 797      798     Kartana         7      grass      steel   Beast Boost
# 798      799    Guzzlord         7       dark     dragon   Beast Boost
# 799      800    Necrozma         7    psychic          -   Prism Armor
# 800      801    Magearna         7      steel      fairy    Soul-Heart
#
#     poke_ability2  base_total   hp  attack  ...  fighting  ice   bug  steel  \
# 0     Chlorophyll         318   45      49  ...       0.5  2.0  1.00    1.0
# 1     Chlorophyll         405   60      62  ...       0.5  2.0  1.00    1.0
# 2     Chlorophyll         625   80     100  ...       0.5  2.0  1.00    1.0
# 3     Solar Power         309   39      52  ...       1.0  0.5  0.50    0.5
# 4     Solar Power         405   58      64  ...       1.0  0.5  0.50    0.5
# ..            ...         ...  ...     ...  ...       ...  ...   ...    ...
# 796             -         570   97     101  ...       1.0  1.0  0.25    0.5
# 797             -         570   59     181  ...       2.0  1.0  1.00    0.5
# 798             -         570  223     101  ...       2.0  2.0  2.00    1.0
# 799             -         600   97     107  ...       0.5  1.0  2.00    1.0
# 800             -         600   80      95  ...       1.0  0.5  0.25    1.0
#
#      poison  psychic  dark  ghost  fairy  dragon
# 0       1.0      2.0   1.0    1.0    0.5     1.0
# 1       1.0      2.0   1.0    1.0    0.5     1.0
# 2       1.0      2.0   1.0    1.0    0.5     1.0
# 3       1.0      1.0   1.0    1.0    0.5     1.0
# 4       1.0      1.0   1.0    1.0    0.5     1.0
# ..      ...      ...   ...    ...    ...     ...
# 796     0.0      0.5   1.0    1.0    0.5     0.5
# 797     0.0      0.5   1.0    1.0    0.5     0.5
# 798     1.0      0.0   0.5    0.5    4.0     2.0
# 799     1.0      0.5   2.0    2.0    1.0     1.0
# 800     0.0      0.5   0.5    1.0    0.5     0.0
#
# [801 rows x 32 columns]
