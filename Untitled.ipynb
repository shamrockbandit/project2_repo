# %%
import csv, sqlite3

con = sqlite3.connect("pokedata.db")
cur = con.cursor()
cur.execute("CREATE TABLE pokedata (poke_ID, poke_name, generation, type1, type2, ability1, ability2, base_total, hp, attack, defense, sp_attack, sp_defense, speed, normal, fire, water, grass, electric, rock, ground, flying, fighting, ice, bug, steel, poison, psychic, dark, ghost, fairy, dragon);") # use your column names here

with open('pokedata_cleaned.csv','r') as fin: # `with` statement available in 2.5+
    # csv.DictReader uses first line in file for column headings by default
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['pokedex_number'], i['name'], i['generation'], i['type1'], i['type2'], i['ability1'], i['ability2'], i['base_total'], i['hp'], i['attack'], i['defense'], i['sp_attack'], i['sp_defense'], i['speed'], i['normal'], i['fire'], i['water'], i['grass'], i['electric'], i['rock'], i['ground'], i['flying'], i['fighting'], i['ice'], i['bug'], i['steel'], i['poison'], i['psychic'], i['dark'], i['ghost'], i['fairy'], i['dragon']) for i in dr]

cur.executemany("INSERT INTO pokedata (poke_ID, poke_name, generation, type1, type2, ability1, ability2, base_total, hp, attack, defense, sp_attack, sp_defense, speed, normal, fire, water, grass, electric, rock, ground, flying, fighting, ice, bug, steel, poison, psychic, dark, ghost, fairy, dragon) VALUES (?, ?,?, ?, ?, ?,?, ?, ?, ?,?, ?, ?, ?,?, ?, ?, ?,?, ?, ?, ?,?, ?, ?, ?,?, ?, ?, ?,?, ?);", to_db)

cur.execute("CREATE TABLE IF NOT EXISTS extra_pokedata (name, image, weakness1, weakness2, weakness3 , weakness4);") # use your column names here

with open('extra_poke.csv','r') as fin: # `with` statement available in 2.5+
#     # csv.DictReader uses first line in file for column headings by default
    reader = csv.reader(fin)
    for field in reader:
        cur.executemany("INSERT INTO extra_pokedata (name, image, weakness1, weakness2, weakness3, weakness4) VALUES (?, ?, ?, ?, ?, ?);", [field])

con.commit()
con.close()

# %%
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///pokedata.db")

# %%
pd.read_sql('SELECT * FROM pokedata', con=engine).to_dict(orient='records')
# Out:
# [{'poke_ID': '1',
#   'poke_name': 'Bulbasaur',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Overgrow',
#   'ability2': 'Chlorophyll',
#   'base_total': '318',
#   'hp': '45',
#   'attack': '49',
#   'defense': '49',
#   'sp_attack': '65',
#   'sp_defense': '65',
#   'speed': '45',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '2',
#   'poke_name': 'Ivysaur',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Overgrow',
#   'ability2': 'Chlorophyll',
#   'base_total': '405',
#   'hp': '60',
#   'attack': '62',
#   'defense': '63',
#   'sp_attack': '80',
#   'sp_defense': '80',
#   'speed': '60',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '3',
#   'poke_name': 'Venusaur',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Overgrow',
#   'ability2': 'Chlorophyll',
#   'base_total': '625',
#   'hp': '80',
#   'attack': '100',
#   'defense': '123',
#   'sp_attack': '122',
#   'sp_defense': '120',
#   'speed': '80',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '4',
#   'poke_name': 'Charmander',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Blaze',
#   'ability2': 'Solar Power',
#   'base_total': '309',
#   'hp': '39',
#   'attack': '52',
#   'defense': '43',
#   'sp_attack': '60',
#   'sp_defense': '50',
#   'speed': '65',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '5',
#   'poke_name': 'Charmeleon',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Blaze',
#   'ability2': 'Solar Power',
#   'base_total': '405',
#   'hp': '58',
#   'attack': '64',
#   'defense': '58',
#   'sp_attack': '80',
#   'sp_defense': '65',
#   'speed': '80',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '6',
#   'poke_name': 'Charizard',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': 'flying',
#   'ability1': 'Blaze',
#   'ability2': 'Solar Power',
#   'base_total': '634',
#   'hp': '78',
#   'attack': '104',
#   'defense': '78',
#   'sp_attack': '159',
#   'sp_defense': '115',
#   'speed': '100',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.25',
#   'electric': '2',
#   'rock': '4',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.25',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '7',
#   'poke_name': 'Squirtle',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Torrent',
#   'ability2': 'Rain Dish',
#   'base_total': '314',
#   'hp': '44',
#   'attack': '48',
#   'defense': '65',
#   'sp_attack': '50',
#   'sp_defense': '64',
#   'speed': '43',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '8',
#   'poke_name': 'Wartortle',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Torrent',
#   'ability2': 'Rain Dish',
#   'base_total': '405',
#   'hp': '59',
#   'attack': '63',
#   'defense': '80',
#   'sp_attack': '65',
#   'sp_defense': '80',
#   'speed': '58',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '9',
#   'poke_name': 'Blastoise',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Torrent',
#   'ability2': 'Rain Dish',
#   'base_total': '630',
#   'hp': '79',
#   'attack': '103',
#   'defense': '120',
#   'sp_attack': '135',
#   'sp_defense': '115',
#   'speed': '78',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '10',
#   'poke_name': 'Caterpie',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': '-',
#   'ability1': 'Shield Dust',
#   'ability2': 'Run Away',
#   'base_total': '195',
#   'hp': '45',
#   'attack': '30',
#   'defense': '35',
#   'sp_attack': '20',
#   'sp_defense': '20',
#   'speed': '45',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '0.5',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '11',
#   'poke_name': 'Metapod',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': '-',
#   'ability1': 'Shed Skin',
#   'ability2': '-',
#   'base_total': '205',
#   'hp': '50',
#   'attack': '20',
#   'defense': '55',
#   'sp_attack': '25',
#   'sp_defense': '25',
#   'speed': '30',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '0.5',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '12',
#   'poke_name': 'Butterfree',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'flying',
#   'ability1': 'Compoundeyes',
#   'ability2': 'Tinted Lens',
#   'base_total': '395',
#   'hp': '60',
#   'attack': '45',
#   'defense': '50',
#   'sp_attack': '90',
#   'sp_defense': '80',
#   'speed': '70',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '2',
#   'rock': '4',
#   'ground': '0',
#   'flying': '2',
#   'fighting': '0.25',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '13',
#   'poke_name': 'Weedle',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'poison',
#   'ability1': 'Shield Dust',
#   'ability2': 'Run Away',
#   'base_total': '195',
#   'hp': '40',
#   'attack': '35',
#   'defense': '30',
#   'sp_attack': '20',
#   'sp_defense': '20',
#   'speed': '50',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '1',
#   'rock': '2',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.25',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '14',
#   'poke_name': 'Kakuna',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'poison',
#   'ability1': 'Shed Skin',
#   'ability2': '-',
#   'base_total': '205',
#   'hp': '45',
#   'attack': '25',
#   'defense': '50',
#   'sp_attack': '25',
#   'sp_defense': '25',
#   'speed': '35',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '1',
#   'rock': '2',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.25',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '15',
#   'poke_name': 'Beedrill',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'poison',
#   'ability1': 'Swarm',
#   'ability2': 'Sniper',
#   'base_total': '495',
#   'hp': '65',
#   'attack': '150',
#   'defense': '40',
#   'sp_attack': '15',
#   'sp_defense': '80',
#   'speed': '145',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '1',
#   'rock': '2',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.25',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '16',
#   'poke_name': 'Pidgey',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'flying',
#   'ability1': 'Keen Eye',
#   'ability2': 'Tangled Feet',
#   'base_total': '251',
#   'hp': '40',
#   'attack': '45',
#   'defense': '40',
#   'sp_attack': '35',
#   'sp_defense': '35',
#   'speed': '56',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '17',
#   'poke_name': 'Pidgeotto',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'flying',
#   'ability1': 'Keen Eye',
#   'ability2': 'Tangled Feet',
#   'base_total': '349',
#   'hp': '63',
#   'attack': '60',
#   'defense': '55',
#   'sp_attack': '50',
#   'sp_defense': '50',
#   'speed': '71',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '18',
#   'poke_name': 'Pidgeot',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'flying',
#   'ability1': 'Keen Eye',
#   'ability2': 'Tangled Feet',
#   'base_total': '579',
#   'hp': '83',
#   'attack': '80',
#   'defense': '80',
#   'sp_attack': '135',
#   'sp_defense': '80',
#   'speed': '121',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '19',
#   'poke_name': 'Rattata',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'dark',
#   'ability1': 'Run Away',
#   'ability2': 'Guts',
#   'base_total': '253',
#   'hp': '30',
#   'attack': '56',
#   'defense': '35',
#   'sp_attack': '25',
#   'sp_defense': '35',
#   'speed': '72',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '20',
#   'poke_name': 'Raticate',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'dark',
#   'ability1': 'Run Away',
#   'ability2': 'Guts',
#   'base_total': '413',
#   'hp': '75',
#   'attack': '71',
#   'defense': '70',
#   'sp_attack': '40',
#   'sp_defense': '80',
#   'speed': '77',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '21',
#   'poke_name': 'Spearow',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'flying',
#   'ability1': 'Keen Eye',
#   'ability2': 'Sniper',
#   'base_total': '262',
#   'hp': '40',
#   'attack': '60',
#   'defense': '30',
#   'sp_attack': '31',
#   'sp_defense': '31',
#   'speed': '70',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '22',
#   'poke_name': 'Fearow',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'flying',
#   'ability1': 'Keen Eye',
#   'ability2': 'Sniper',
#   'base_total': '442',
#   'hp': '65',
#   'attack': '90',
#   'defense': '65',
#   'sp_attack': '61',
#   'sp_defense': '61',
#   'speed': '100',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '23',
#   'poke_name': 'Ekans',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': '-',
#   'ability1': 'Intimidate',
#   'ability2': 'Shed Skin',
#   'base_total': '288',
#   'hp': '35',
#   'attack': '60',
#   'defense': '44',
#   'sp_attack': '40',
#   'sp_defense': '54',
#   'speed': '55',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '24',
#   'poke_name': 'Arbok',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': '-',
#   'ability1': 'Intimidate',
#   'ability2': 'Shed Skin',
#   'base_total': '448',
#   'hp': '60',
#   'attack': '95',
#   'defense': '69',
#   'sp_attack': '65',
#   'sp_defense': '79',
#   'speed': '80',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '25',
#   'poke_name': 'Pikachu',
#   'generation': '1',
#   'type1': 'electric',
#   'type2': '-',
#   'ability1': 'Static',
#   'ability2': 'Lightningrod',
#   'base_total': '320',
#   'hp': '35',
#   'attack': '55',
#   'defense': '40',
#   'sp_attack': '50',
#   'sp_defense': '50',
#   'speed': '90',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '26',
#   'poke_name': 'Raichu',
#   'generation': '1',
#   'type1': 'electric',
#   'type2': '-',
#   'ability1': 'Static',
#   'ability2': 'Lightningrod',
#   'base_total': '485',
#   'hp': '60',
#   'attack': '85',
#   'defense': '50',
#   'sp_attack': '95',
#   'sp_defense': '85',
#   'speed': '110',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '27',
#   'poke_name': 'Sandshrew',
#   'generation': '1',
#   'type1': 'ground',
#   'type2': 'ice',
#   'ability1': 'Sand Veil',
#   'ability2': 'Sand Rush',
#   'base_total': '300',
#   'hp': '50',
#   'attack': '75',
#   'defense': '90',
#   'sp_attack': '10',
#   'sp_defense': '35',
#   'speed': '40',
#   'normal': '1',
#   'fire': '1',
#   'water': '2',
#   'grass': '2',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '28',
#   'poke_name': 'Sandslash',
#   'generation': '1',
#   'type1': 'ground',
#   'type2': 'ice',
#   'ability1': 'Sand Veil',
#   'ability2': 'Sand Rush',
#   'base_total': '450',
#   'hp': '75',
#   'attack': '100',
#   'defense': '120',
#   'sp_attack': '25',
#   'sp_defense': '65',
#   'speed': '65',
#   'normal': '1',
#   'fire': '1',
#   'water': '2',
#   'grass': '2',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '29',
#   'poke_name': 'NidoranÃ¢Â™Â€',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': '-',
#   'ability1': 'Poison Point',
#   'ability2': 'Rivalry',
#   'base_total': '275',
#   'hp': '55',
#   'attack': '47',
#   'defense': '52',
#   'sp_attack': '40',
#   'sp_defense': '40',
#   'speed': '41',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '30',
#   'poke_name': 'Nidorina',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': '-',
#   'ability1': 'Poison Point',
#   'ability2': 'Rivalry',
#   'base_total': '365',
#   'hp': '70',
#   'attack': '62',
#   'defense': '67',
#   'sp_attack': '55',
#   'sp_defense': '55',
#   'speed': '56',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '31',
#   'poke_name': 'Nidoqueen',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': 'ground',
#   'ability1': 'Poison Point',
#   'ability2': 'Rivalry',
#   'base_total': '505',
#   'hp': '90',
#   'attack': '92',
#   'defense': '87',
#   'sp_attack': '75',
#   'sp_defense': '85',
#   'speed': '76',
#   'normal': '1',
#   'fire': '1',
#   'water': '2',
#   'grass': '1',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.25',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '32',
#   'poke_name': 'NidoranÃ¢Â™Â‚',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': '-',
#   'ability1': 'Poison Point',
#   'ability2': 'Rivalry',
#   'base_total': '273',
#   'hp': '46',
#   'attack': '57',
#   'defense': '40',
#   'sp_attack': '40',
#   'sp_defense': '40',
#   'speed': '50',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '33',
#   'poke_name': 'Nidorino',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': '-',
#   'ability1': 'Poison Point',
#   'ability2': 'Rivalry',
#   'base_total': '365',
#   'hp': '61',
#   'attack': '72',
#   'defense': '57',
#   'sp_attack': '55',
#   'sp_defense': '55',
#   'speed': '65',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '34',
#   'poke_name': 'Nidoking',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': 'ground',
#   'ability1': 'Poison Point',
#   'ability2': 'Rivalry',
#   'base_total': '505',
#   'hp': '81',
#   'attack': '102',
#   'defense': '77',
#   'sp_attack': '85',
#   'sp_defense': '75',
#   'speed': '85',
#   'normal': '1',
#   'fire': '1',
#   'water': '2',
#   'grass': '1',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.25',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '35',
#   'poke_name': 'Clefairy',
#   'generation': '1',
#   'type1': 'fairy',
#   'type2': '-',
#   'ability1': 'Cute Charm',
#   'ability2': 'Magic Guard',
#   'base_total': '323',
#   'hp': '70',
#   'attack': '45',
#   'defense': '48',
#   'sp_attack': '60',
#   'sp_defense': '65',
#   'speed': '35',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '2',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '36',
#   'poke_name': 'Clefable',
#   'generation': '1',
#   'type1': 'fairy',
#   'type2': '-',
#   'ability1': 'Cute Charm',
#   'ability2': 'Magic Guard',
#   'base_total': '483',
#   'hp': '95',
#   'attack': '70',
#   'defense': '73',
#   'sp_attack': '95',
#   'sp_defense': '90',
#   'speed': '60',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '2',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '37',
#   'poke_name': 'Vulpix',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Flash Fire',
#   'ability2': 'Drought',
#   'base_total': '299',
#   'hp': '38',
#   'attack': '41',
#   'defense': '40',
#   'sp_attack': '50',
#   'sp_defense': '65',
#   'speed': '65',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '38',
#   'poke_name': 'Ninetales',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Flash Fire',
#   'ability2': 'Drought',
#   'base_total': '505',
#   'hp': '73',
#   'attack': '67',
#   'defense': '75',
#   'sp_attack': '81',
#   'sp_defense': '100',
#   'speed': '109',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '39',
#   'poke_name': 'Jigglypuff',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'fairy',
#   'ability1': 'Cute Charm',
#   'ability2': 'Competitive',
#   'base_total': '270',
#   'hp': '115',
#   'attack': '45',
#   'defense': '20',
#   'sp_attack': '45',
#   'sp_defense': '25',
#   'speed': '20',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '2',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '40',
#   'poke_name': 'Wigglytuff',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': 'fairy',
#   'ability1': 'Cute Charm',
#   'ability2': 'Competitive',
#   'base_total': '435',
#   'hp': '140',
#   'attack': '70',
#   'defense': '45',
#   'sp_attack': '85',
#   'sp_defense': '50',
#   'speed': '45',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '2',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '41',
#   'poke_name': 'Zubat',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': 'flying',
#   'ability1': 'Inner Focus',
#   'ability2': 'Infiltrator',
#   'base_total': '245',
#   'hp': '40',
#   'attack': '45',
#   'defense': '35',
#   'sp_attack': '30',
#   'sp_defense': '40',
#   'speed': '55',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '0.25',
#   'ice': '2',
#   'bug': '0.25',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '42',
#   'poke_name': 'Golbat',
#   'generation': '1',
#   'type1': 'poison',
#   'type2': 'flying',
#   'ability1': 'Inner Focus',
#   'ability2': 'Infiltrator',
#   'base_total': '455',
#   'hp': '75',
#   'attack': '80',
#   'defense': '70',
#   'sp_attack': '65',
#   'sp_defense': '75',
#   'speed': '90',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '2',
#   'rock': '2',
#   'ground': '0',
#   'flying': '1',
#   'fighting': '0.25',
#   'ice': '2',
#   'bug': '0.25',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '43',
#   'poke_name': 'Oddish',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Chlorophyll',
#   'ability2': 'Run Away',
#   'base_total': '320',
#   'hp': '45',
#   'attack': '50',
#   'defense': '55',
#   'sp_attack': '75',
#   'sp_defense': '65',
#   'speed': '30',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '44',
#   'poke_name': 'Gloom',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Chlorophyll',
#   'ability2': 'Stench',
#   'base_total': '395',
#   'hp': '60',
#   'attack': '65',
#   'defense': '70',
#   'sp_attack': '85',
#   'sp_defense': '75',
#   'speed': '40',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '45',
#   'poke_name': 'Vileplume',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Chlorophyll',
#   'ability2': 'Effect Spore',
#   'base_total': '490',
#   'hp': '75',
#   'attack': '80',
#   'defense': '85',
#   'sp_attack': '110',
#   'sp_defense': '90',
#   'speed': '50',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '46',
#   'poke_name': 'Paras',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'grass',
#   'ability1': 'Effect Spore',
#   'ability2': 'Dry Skin',
#   'base_total': '285',
#   'hp': '35',
#   'attack': '70',
#   'defense': '55',
#   'sp_attack': '45',
#   'sp_defense': '55',
#   'speed': '25',
#   'normal': '1',
#   'fire': '4',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '2',
#   'ground': '0.25',
#   'flying': '4',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '2',
#   'steel': '1',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '47',
#   'poke_name': 'Parasect',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'grass',
#   'ability1': 'Effect Spore',
#   'ability2': 'Dry Skin',
#   'base_total': '405',
#   'hp': '60',
#   'attack': '95',
#   'defense': '80',
#   'sp_attack': '60',
#   'sp_defense': '80',
#   'speed': '30',
#   'normal': '1',
#   'fire': '4',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '2',
#   'ground': '0.25',
#   'flying': '4',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '2',
#   'steel': '1',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '48',
#   'poke_name': 'Venonat',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'poison',
#   'ability1': 'Compoundeyes',
#   'ability2': 'Tinted Lens',
#   'base_total': '305',
#   'hp': '60',
#   'attack': '55',
#   'defense': '50',
#   'sp_attack': '40',
#   'sp_defense': '55',
#   'speed': '45',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '1',
#   'rock': '2',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.25',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '49',
#   'poke_name': 'Venomoth',
#   'generation': '1',
#   'type1': 'bug',
#   'type2': 'poison',
#   'ability1': 'Shield Dust',
#   'ability2': 'Tinted Lens',
#   'base_total': '450',
#   'hp': '70',
#   'attack': '65',
#   'defense': '60',
#   'sp_attack': '90',
#   'sp_defense': '75',
#   'speed': '90',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '1',
#   'rock': '2',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.25',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '50',
#   'poke_name': 'Diglett',
#   'generation': '1',
#   'type1': 'ground',
#   'type2': '-',
#   'ability1': 'Sand Veil',
#   'ability2': 'Arena Trap',
#   'base_total': '265',
#   'hp': '10',
#   'attack': '55',
#   'defense': '30',
#   'sp_attack': '35',
#   'sp_defense': '45',
#   'speed': '90',
#   'normal': '1',
#   'fire': '1',
#   'water': '2',
#   'grass': '2',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '51',
#   'poke_name': 'Dugtrio',
#   'generation': '1',
#   'type1': 'ground',
#   'type2': '-',
#   'ability1': 'Sand Veil',
#   'ability2': 'Arena Trap',
#   'base_total': '425',
#   'hp': '35',
#   'attack': '100',
#   'defense': '60',
#   'sp_attack': '50',
#   'sp_defense': '70',
#   'speed': '110',
#   'normal': '1',
#   'fire': '1',
#   'water': '2',
#   'grass': '2',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '52',
#   'poke_name': 'Meowth',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': '-',
#   'ability1': 'Pickup',
#   'ability2': 'Technician',
#   'base_total': '290',
#   'hp': '40',
#   'attack': '35',
#   'defense': '35',
#   'sp_attack': '50',
#   'sp_defense': '40',
#   'speed': '90',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '53',
#   'poke_name': 'Persian',
#   'generation': '1',
#   'type1': 'normal',
#   'type2': '-',
#   'ability1': 'Limber',
#   'ability2': 'Technician',
#   'base_total': '440',
#   'hp': '65',
#   'attack': '60',
#   'defense': '60',
#   'sp_attack': '75',
#   'sp_defense': '65',
#   'speed': '115',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '54',
#   'poke_name': 'Psyduck',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Damp',
#   'ability2': 'Cloud Nine',
#   'base_total': '320',
#   'hp': '50',
#   'attack': '52',
#   'defense': '48',
#   'sp_attack': '65',
#   'sp_defense': '50',
#   'speed': '55',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '55',
#   'poke_name': 'Golduck',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Damp',
#   'ability2': 'Cloud Nine',
#   'base_total': '500',
#   'hp': '80',
#   'attack': '82',
#   'defense': '78',
#   'sp_attack': '95',
#   'sp_defense': '80',
#   'speed': '85',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '56',
#   'poke_name': 'Mankey',
#   'generation': '1',
#   'type1': 'fighting',
#   'type2': '-',
#   'ability1': 'Vital Spirit',
#   'ability2': 'Anger Point',
#   'base_total': '305',
#   'hp': '40',
#   'attack': '80',
#   'defense': '35',
#   'sp_attack': '35',
#   'sp_defense': '45',
#   'speed': '70',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '57',
#   'poke_name': 'Primeape',
#   'generation': '1',
#   'type1': 'fighting',
#   'type2': '-',
#   'ability1': 'Vital Spirit',
#   'ability2': 'Anger Point',
#   'base_total': '455',
#   'hp': '65',
#   'attack': '105',
#   'defense': '60',
#   'sp_attack': '60',
#   'sp_defense': '70',
#   'speed': '95',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '58',
#   'poke_name': 'Growlithe',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Intimidate',
#   'ability2': 'Flash Fire',
#   'base_total': '350',
#   'hp': '55',
#   'attack': '70',
#   'defense': '45',
#   'sp_attack': '70',
#   'sp_defense': '50',
#   'speed': '60',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '59',
#   'poke_name': 'Arcanine',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Intimidate',
#   'ability2': 'Flash Fire',
#   'base_total': '555',
#   'hp': '90',
#   'attack': '110',
#   'defense': '80',
#   'sp_attack': '100',
#   'sp_defense': '80',
#   'speed': '95',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '60',
#   'poke_name': 'Poliwag',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Water Absorb',
#   'ability2': 'Damp',
#   'base_total': '300',
#   'hp': '40',
#   'attack': '50',
#   'defense': '40',
#   'sp_attack': '40',
#   'sp_defense': '40',
#   'speed': '90',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '61',
#   'poke_name': 'Poliwhirl',
#   'generation': '1',
#   'type1': 'water',
#   'type2': '-',
#   'ability1': 'Water Absorb',
#   'ability2': 'Damp',
#   'base_total': '385',
#   'hp': '65',
#   'attack': '65',
#   'defense': '65',
#   'sp_attack': '50',
#   'sp_defense': '50',
#   'speed': '90',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '62',
#   'poke_name': 'Poliwrath',
#   'generation': '1',
#   'type1': 'water',
#   'type2': 'fighting',
#   'ability1': 'Water Absorb',
#   'ability2': 'Damp',
#   'base_total': '510',
#   'hp': '90',
#   'attack': '95',
#   'defense': '95',
#   'sp_attack': '70',
#   'sp_defense': '90',
#   'speed': '70',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '63',
#   'poke_name': 'Abra',
#   'generation': '1',
#   'type1': 'psychic',
#   'type2': '-',
#   'ability1': 'Synchronize',
#   'ability2': 'Inner Focus',
#   'base_total': '310',
#   'hp': '25',
#   'attack': '20',
#   'defense': '15',
#   'sp_attack': '105',
#   'sp_defense': '55',
#   'speed': '90',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '64',
#   'poke_name': 'Kadabra',
#   'generation': '1',
#   'type1': 'psychic',
#   'type2': '-',
#   'ability1': 'Synchronize',
#   'ability2': 'Inner Focus',
#   'base_total': '400',
#   'hp': '40',
#   'attack': '35',
#   'defense': '30',
#   'sp_attack': '120',
#   'sp_defense': '70',
#   'speed': '105',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '65',
#   'poke_name': 'Alakazam',
#   'generation': '1',
#   'type1': 'psychic',
#   'type2': '-',
#   'ability1': 'Synchronize',
#   'ability2': 'Inner Focus',
#   'base_total': '600',
#   'hp': '55',
#   'attack': '50',
#   'defense': '65',
#   'sp_attack': '175',
#   'sp_defense': '105',
#   'speed': '150',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '66',
#   'poke_name': 'Machop',
#   'generation': '1',
#   'type1': 'fighting',
#   'type2': '-',
#   'ability1': 'Guts',
#   'ability2': 'No Guard',
#   'base_total': '305',
#   'hp': '70',
#   'attack': '80',
#   'defense': '50',
#   'sp_attack': '35',
#   'sp_defense': '35',
#   'speed': '35',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '67',
#   'poke_name': 'Machoke',
#   'generation': '1',
#   'type1': 'fighting',
#   'type2': '-',
#   'ability1': 'Guts',
#   'ability2': 'No Guard',
#   'base_total': '405',
#   'hp': '80',
#   'attack': '100',
#   'defense': '70',
#   'sp_attack': '50',
#   'sp_defense': '60',
#   'speed': '45',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '68',
#   'poke_name': 'Machamp',
#   'generation': '1',
#   'type1': 'fighting',
#   'type2': '-',
#   'ability1': 'Guts',
#   'ability2': 'No Guard',
#   'base_total': '505',
#   'hp': '90',
#   'attack': '130',
#   'defense': '80',
#   'sp_attack': '65',
#   'sp_defense': '85',
#   'speed': '55',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '69',
#   'poke_name': 'Bellsprout',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Chlorophyll',
#   'ability2': 'Gluttony',
#   'base_total': '300',
#   'hp': '50',
#   'attack': '75',
#   'defense': '35',
#   'sp_attack': '70',
#   'sp_defense': '30',
#   'speed': '40',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '70',
#   'poke_name': 'Weepinbell',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Chlorophyll',
#   'ability2': 'Gluttony',
#   'base_total': '390',
#   'hp': '65',
#   'attack': '90',
#   'defense': '50',
#   'sp_attack': '85',
#   'sp_defense': '45',
#   'speed': '55',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '71',
#   'poke_name': 'Victreebel',
#   'generation': '1',
#   'type1': 'grass',
#   'type2': 'poison',
#   'ability1': 'Chlorophyll',
#   'ability2': 'Gluttony',
#   'base_total': '490',
#   'hp': '80',
#   'attack': '105',
#   'defense': '65',
#   'sp_attack': '100',
#   'sp_defense': '70',
#   'speed': '70',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '72',
#   'poke_name': 'Tentacool',
#   'generation': '1',
#   'type1': 'water',
#   'type2': 'poison',
#   'ability1': 'Clear Body',
#   'ability2': 'Liquid Ooze',
#   'base_total': '335',
#   'hp': '40',
#   'attack': '40',
#   'defense': '35',
#   'sp_attack': '50',
#   'sp_defense': '100',
#   'speed': '70',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '1',
#   'electric': '2',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '73',
#   'poke_name': 'Tentacruel',
#   'generation': '1',
#   'type1': 'water',
#   'type2': 'poison',
#   'ability1': 'Clear Body',
#   'ability2': 'Liquid Ooze',
#   'base_total': '515',
#   'hp': '80',
#   'attack': '70',
#   'defense': '65',
#   'sp_attack': '80',
#   'sp_defense': '120',
#   'speed': '100',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '1',
#   'electric': '2',
#   'rock': '1',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '0.5',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '74',
#   'poke_name': 'Geodude',
#   'generation': '1',
#   'type1': 'rock',
#   'type2': 'ground',
#   'ability1': 'Rock Head',
#   'ability2': 'Sturdy',
#   'base_total': '300',
#   'hp': '40',
#   'attack': '80',
#   'defense': '100',
#   'sp_attack': '30',
#   'sp_defense': '30',
#   'speed': '20',
#   'normal': '0.5',
#   'fire': '0.5',
#   'water': '4',
#   'grass': '4',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '2',
#   'ice': '2',
#   'bug': '1',
#   'steel': '2',
#   'poison': '0.25',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '75',
#   'poke_name': 'Graveler',
#   'generation': '1',
#   'type1': 'rock',
#   'type2': 'ground',
#   'ability1': 'Rock Head',
#   'ability2': 'Sturdy',
#   'base_total': '390',
#   'hp': '55',
#   'attack': '95',
#   'defense': '115',
#   'sp_attack': '45',
#   'sp_defense': '45',
#   'speed': '35',
#   'normal': '0.5',
#   'fire': '0.5',
#   'water': '4',
#   'grass': '4',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '2',
#   'ice': '2',
#   'bug': '1',
#   'steel': '2',
#   'poison': '0.25',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '76',
#   'poke_name': 'Golem',
#   'generation': '1',
#   'type1': 'rock',
#   'type2': 'ground',
#   'ability1': 'Rock Head',
#   'ability2': 'Sturdy',
#   'base_total': '495',
#   'hp': '80',
#   'attack': '120',
#   'defense': '130',
#   'sp_attack': '55',
#   'sp_defense': '65',
#   'speed': '45',
#   'normal': '0.5',
#   'fire': '0.5',
#   'water': '4',
#   'grass': '4',
#   'electric': '0',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '2',
#   'ice': '2',
#   'bug': '1',
#   'steel': '2',
#   'poison': '0.25',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '77',
#   'poke_name': 'Ponyta',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Run Away',
#   'ability2': 'Flash Fire',
#   'base_total': '410',
#   'hp': '50',
#   'attack': '85',
#   'defense': '55',
#   'sp_attack': '65',
#   'sp_defense': '65',
#   'speed': '90',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '78',
#   'poke_name': 'Rapidash',
#   'generation': '1',
#   'type1': 'fire',
#   'type2': '-',
#   'ability1': 'Run Away',
#   'ability2': 'Flash Fire',
#   'base_total': '500',
#   'hp': '65',
#   'attack': '100',
#   'defense': '70',
#   'sp_attack': '80',
#   'sp_defense': '80',
#   'speed': '105',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '79',
#   'poke_name': 'Slowpoke',
#   'generation': '1',
#   'type1': 'water',
#   'type2': 'psychic',
#   'ability1': 'Oblivious',
#   'ability2': 'Own Tempo',
#   'base_total': '315',
#   'hp': '90',
#   'attack': '65',
#   'defense': '65',
#   'sp_attack': '40',
#   'sp_defense': '40',
#   'speed': '15',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '0.5',
#   'bug': '2',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '80',
#   'poke_name': 'Slowbro',
#   'generation': '1',
#   'type1': 'water',
#   'type2': 'psychic',
#   'ability1': 'Oblivious',
#   'ability2': 'Own Tempo',
#   'base_total': '590',
#   'hp': '95',
#   'attack': '75',
#   'defense': '180',
#   'sp_attack': '130',
#   'sp_defense': '80',
#   'speed': '30',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '0.5',
#   'bug': '2',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '81',
#   'poke_name': 'Magnemite',
#   'generation': '1',
#   'type1': 'electric',
#   'type2': 'steel',
#   'ability1': 'Magnet Pull',
#   'ability2': 'Sturdy',
#   'base_total': '325',
# ...
#   'sp_attack': '75',
#   'sp_defense': '95',
#   'speed': '65',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '776',
#   'poke_name': 'Turtonator',
#   'generation': '7',
#   'type1': 'fire',
#   'type2': 'dragon',
#   'ability1': 'Shell Armor',
#   'ability2': '-',
#   'base_total': '485',
#   'hp': '60',
#   'attack': '78',
#   'defense': '135',
#   'sp_attack': '91',
#   'sp_defense': '85',
#   'speed': '36',
#   'normal': '1',
#   'fire': '0.25',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '2',
#   'ground': '2',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '2'},
#  {'poke_ID': '777',
#   'poke_name': 'Togedemaru',
#   'generation': '7',
#   'type1': 'electric',
#   'type2': 'steel',
#   'ability1': 'Iron Barbs',
#   'ability2': 'Lightningrod',
#   'base_total': '435',
#   'hp': '65',
#   'attack': '98',
#   'defense': '63',
#   'sp_attack': '40',
#   'sp_defense': '73',
#   'speed': '96',
#   'normal': '0.5',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '0.5',
#   'ground': '4',
#   'flying': '0.25',
#   'fighting': '2',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '0.25',
#   'poison': '0',
#   'psychic': '0.5',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '0.5'},
#  {'poke_ID': '778',
#   'poke_name': 'Mimikyu',
#   'generation': '7',
#   'type1': 'ghost',
#   'type2': 'fairy',
#   'ability1': 'Disguise',
#   'ability2': '-',
#   'base_total': '476',
#   'hp': '55',
#   'attack': '90',
#   'defense': '80',
#   'sp_attack': '50',
#   'sp_defense': '105',
#   'speed': '96',
#   'normal': '0',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0',
#   'ice': '1',
#   'bug': '0.25',
#   'steel': '2',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '779',
#   'poke_name': 'Bruxish',
#   'generation': '7',
#   'type1': 'water',
#   'type2': 'psychic',
#   'ability1': 'Dazzling',
#   'ability2': 'Strong Jaw',
#   'base_total': '475',
#   'hp': '68',
#   'attack': '105',
#   'defense': '70',
#   'sp_attack': '70',
#   'sp_defense': '70',
#   'speed': '92',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '0.5',
#   'bug': '2',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '780',
#   'poke_name': 'Drampa',
#   'generation': '7',
#   'type1': 'normal',
#   'type2': 'dragon',
#   'ability1': 'Berserk',
#   'ability2': 'Sap Sipper',
#   'base_total': '485',
#   'hp': '78',
#   'attack': '60',
#   'defense': '85',
#   'sp_attack': '135',
#   'sp_defense': '91',
#   'speed': '36',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '0',
#   'fairy': '2',
#   'dragon': '2'},
#  {'poke_ID': '781',
#   'poke_name': 'Dhelmise',
#   'generation': '7',
#   'type1': 'ghost',
#   'type2': 'grass',
#   'ability1': 'Steelworker',
#   'ability2': '-',
#   'base_total': '517',
#   'hp': '70',
#   'attack': '131',
#   'defense': '100',
#   'sp_attack': '86',
#   'sp_defense': '90',
#   'speed': '40',
#   'normal': '0',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '0.5',
#   'flying': '2',
#   'fighting': '0',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '782',
#   'poke_name': 'Jangmo-o',
#   'generation': '7',
#   'type1': 'dragon',
#   'type2': '-',
#   'ability1': 'Bulletproof',
#   'ability2': 'Soundproof',
#   'base_total': '300',
#   'hp': '45',
#   'attack': '55',
#   'defense': '65',
#   'sp_attack': '45',
#   'sp_defense': '45',
#   'speed': '45',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '1',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '2'},
#  {'poke_ID': '783',
#   'poke_name': 'Hakamo-o',
#   'generation': '7',
#   'type1': 'dragon',
#   'type2': 'fighting',
#   'ability1': 'Bulletproof',
#   'ability2': 'Soundproof',
#   'base_total': '420',
#   'hp': '55',
#   'attack': '75',
#   'defense': '90',
#   'sp_attack': '65',
#   'sp_defense': '70',
#   'speed': '65',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '4',
#   'dragon': '2'},
#  {'poke_ID': '784',
#   'poke_name': 'Kommo-o',
#   'generation': '7',
#   'type1': 'dragon',
#   'type2': 'fighting',
#   'ability1': 'Bulletproof',
#   'ability2': 'Soundproof',
#   'base_total': '600',
#   'hp': '75',
#   'attack': '110',
#   'defense': '125',
#   'sp_attack': '100',
#   'sp_defense': '105',
#   'speed': '85',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '2',
#   'fighting': '1',
#   'ice': '2',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '4',
#   'dragon': '2'},
#  {'poke_ID': '785',
#   'poke_name': 'Tapu Koko',
#   'generation': '7',
#   'type1': 'electric',
#   'type2': 'fairy',
#   'ability1': 'Electric Surge',
#   'ability2': 'Telepathy',
#   'base_total': '570',
#   'hp': '70',
#   'attack': '115',
#   'defense': '85',
#   'sp_attack': '95',
#   'sp_defense': '75',
#   'speed': '130',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '786',
#   'poke_name': 'Tapu Lele',
#   'generation': '7',
#   'type1': 'psychic',
#   'type2': 'fairy',
#   'ability1': 'Psychic Surge',
#   'ability2': 'Telepathy',
#   'base_total': '570',
#   'hp': '70',
#   'attack': '85',
#   'defense': '75',
#   'sp_attack': '130',
#   'sp_defense': '115',
#   'speed': '95',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.25',
#   'ice': '1',
#   'bug': '1',
#   'steel': '2',
#   'poison': '2',
#   'psychic': '0.5',
#   'dark': '1',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '787',
#   'poke_name': 'Tapu Bulu',
#   'generation': '7',
#   'type1': 'grass',
#   'type2': 'fairy',
#   'ability1': 'Grassy Surge',
#   'ability2': 'Telepathy',
#   'base_total': '570',
#   'hp': '70',
#   'attack': '130',
#   'defense': '115',
#   'sp_attack': '85',
#   'sp_defense': '95',
#   'speed': '75',
#   'normal': '1',
#   'fire': '2',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '0.5',
#   'flying': '2',
#   'fighting': '0.5',
#   'ice': '2',
#   'bug': '1',
#   'steel': '2',
#   'poison': '4',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '788',
#   'poke_name': 'Tapu Fini',
#   'generation': '7',
#   'type1': 'water',
#   'type2': 'fairy',
#   'ability1': 'Misty Surge',
#   'ability2': 'Telepathy',
#   'base_total': '570',
#   'hp': '70',
#   'attack': '75',
#   'defense': '115',
#   'sp_attack': '95',
#   'sp_defense': '130',
#   'speed': '85',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '2',
#   'electric': '2',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '0.5',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '2',
#   'psychic': '1',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '0'},
#  {'poke_ID': '789',
#   'poke_name': 'Cosmog',
#   'generation': '7',
#   'type1': 'psychic',
#   'type2': '-',
#   'ability1': 'Unaware',
#   'ability2': '-',
#   'base_total': '200',
#   'hp': '43',
#   'attack': '29',
#   'defense': '31',
#   'sp_attack': '29',
#   'sp_defense': '31',
#   'speed': '37',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '790',
#   'poke_name': 'Cosmoem',
#   'generation': '7',
#   'type1': 'psychic',
#   'type2': '-',
#   'ability1': 'Sturdy',
#   'ability2': '-',
#   'base_total': '400',
#   'hp': '43',
#   'attack': '29',
#   'defense': '131',
#   'sp_attack': '29',
#   'sp_defense': '131',
#   'speed': '37',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '791',
#   'poke_name': 'Solgaleo',
#   'generation': '7',
#   'type1': 'psychic',
#   'type2': 'steel',
#   'ability1': 'Full Metal Body',
#   'ability2': '-',
#   'base_total': '680',
#   'hp': '137',
#   'attack': '137',
#   'defense': '107',
#   'sp_attack': '113',
#   'sp_defense': '89',
#   'speed': '97',
#   'normal': '0.5',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '0',
#   'psychic': '0.25',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '0.5',
#   'dragon': '0.5'},
#  {'poke_ID': '792',
#   'poke_name': 'Lunala',
#   'generation': '7',
#   'type1': 'psychic',
#   'type2': 'ghost',
#   'ability1': 'Shadow Shield',
#   'ability2': '-',
#   'base_total': '680',
#   'hp': '137',
#   'attack': '113',
#   'defense': '89',
#   'sp_attack': '137',
#   'sp_defense': '107',
#   'speed': '97',
#   'normal': '0',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0',
#   'ice': '1',
#   'bug': '1',
#   'steel': '1',
#   'poison': '0.5',
#   'psychic': '0.5',
#   'dark': '4',
#   'ghost': '4',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '793',
#   'poke_name': 'Nihilego',
#   'generation': '7',
#   'type1': 'rock',
#   'type2': 'poison',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '109',
#   'attack': '53',
#   'defense': '47',
#   'sp_attack': '127',
#   'sp_defense': '131',
#   'speed': '103',
#   'normal': '0.5',
#   'fire': '0.5',
#   'water': '2',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '4',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '2',
#   'poison': '0.25',
#   'psychic': '2',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '1'},
#  {'poke_ID': '794',
#   'poke_name': 'Buzzwole',
#   'generation': '7',
#   'type1': 'bug',
#   'type2': 'fighting',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '107',
#   'attack': '139',
#   'defense': '139',
#   'sp_attack': '53',
#   'sp_defense': '53',
#   'speed': '79',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '0.5',
#   'flying': '4',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '795',
#   'poke_name': 'Pheromosa',
#   'generation': '7',
#   'type1': 'bug',
#   'type2': 'fighting',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '71',
#   'attack': '137',
#   'defense': '37',
#   'sp_attack': '137',
#   'sp_defense': '37',
#   'speed': '151',
#   'normal': '1',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '1',
#   'ground': '0.5',
#   'flying': '4',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '0.5',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '2',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '2',
#   'dragon': '1'},
#  {'poke_ID': '796',
#   'poke_name': 'Xurkitree',
#   'generation': '7',
#   'type1': 'electric',
#   'type2': '-',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '83',
#   'attack': '89',
#   'defense': '71',
#   'sp_attack': '173',
#   'sp_defense': '71',
#   'speed': '83',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '1',
#   'psychic': '1',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '797',
#   'poke_name': 'Celesteela',
#   'generation': '7',
#   'type1': 'steel',
#   'type2': 'flying',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '97',
#   'attack': '101',
#   'defense': '103',
#   'sp_attack': '107',
#   'sp_defense': '101',
#   'speed': '61',
#   'normal': '0.5',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.25',
#   'electric': '2',
#   'rock': '1',
#   'ground': '0',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '1',
#   'bug': '0.25',
#   'steel': '0.5',
#   'poison': '0',
#   'psychic': '0.5',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '0.5'},
#  {'poke_ID': '798',
#   'poke_name': 'Kartana',
#   'generation': '7',
#   'type1': 'grass',
#   'type2': 'steel',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '59',
#   'attack': '181',
#   'defense': '131',
#   'sp_attack': '59',
#   'sp_defense': '31',
#   'speed': '109',
#   'normal': '0.5',
#   'fire': '4',
#   'water': '0.5',
#   'grass': '0.25',
#   'electric': '0.5',
#   'rock': '0.5',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '1',
#   'bug': '1',
#   'steel': '0.5',
#   'poison': '0',
#   'psychic': '0.5',
#   'dark': '1',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '0.5'},
#  {'poke_ID': '799',
#   'poke_name': 'Guzzlord',
#   'generation': '7',
#   'type1': 'dark',
#   'type2': 'dragon',
#   'ability1': 'Beast Boost',
#   'ability2': '-',
#   'base_total': '570',
#   'hp': '223',
#   'attack': '101',
#   'defense': '53',
#   'sp_attack': '97',
#   'sp_defense': '53',
#   'speed': '43',
#   'normal': '1',
#   'fire': '0.5',
#   'water': '0.5',
#   'grass': '0.5',
#   'electric': '0.5',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '2',
#   'ice': '2',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0',
#   'dark': '0.5',
#   'ghost': '0.5',
#   'fairy': '4',
#   'dragon': '2'},
#  {'poke_ID': '800',
#   'poke_name': 'Necrozma',
#   'generation': '7',
#   'type1': 'psychic',
#   'type2': '-',
#   'ability1': 'Prism Armor',
#   'ability2': '-',
#   'base_total': '600',
#   'hp': '97',
#   'attack': '107',
#   'defense': '101',
#   'sp_attack': '127',
#   'sp_defense': '89',
#   'speed': '79',
#   'normal': '1',
#   'fire': '1',
#   'water': '1',
#   'grass': '1',
#   'electric': '1',
#   'rock': '1',
#   'ground': '1',
#   'flying': '1',
#   'fighting': '0.5',
#   'ice': '1',
#   'bug': '2',
#   'steel': '1',
#   'poison': '1',
#   'psychic': '0.5',
#   'dark': '2',
#   'ghost': '2',
#   'fairy': '1',
#   'dragon': '1'},
#  {'poke_ID': '801',
#   'poke_name': 'Magearna',
#   'generation': '7',
#   'type1': 'steel',
#   'type2': 'fairy',
#   'ability1': 'Soul-Heart',
#   'ability2': '-',
#   'base_total': '600',
#   'hp': '80',
#   'attack': '95',
#   'defense': '115',
#   'sp_attack': '130',
#   'sp_defense': '115',
#   'speed': '65',
#   'normal': '0.5',
#   'fire': '2',
#   'water': '1',
#   'grass': '0.5',
#   'electric': '1',
#   'rock': '0.5',
#   'ground': '2',
#   'flying': '0.5',
#   'fighting': '1',
#   'ice': '0.5',
#   'bug': '0.25',
#   'steel': '1',
#   'poison': '0',
#   'psychic': '0.5',
#   'dark': '0.5',
#   'ghost': '1',
#   'fairy': '0.5',
#   'dragon': '0'}]

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Invoices = Base.classes.pokedata
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'pokedata'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4ee83a694a4c> in <module>
#       1 Base = automap_base()
#       2 Base.prepare(engine, reflect=True)
# ----> 3 Invoices = Base.classes.pokedata
#
# ~\anaconda\envs\PythonData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: pokedata

# %%
inspector = inspect(engine)

tableName = inspector.get_table_names()
print(len(engine.table_names()))
print(tableName)
# Out:
# 2
# ['extra_pokedata', 'pokedata']

# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd
from pandas.io.json import json_normalize
import json
Database_URI = "postgres+psycopg2://postgres:postgres@localhost/Pokemon"
engine = create_engine(Database_URI)
data = pd.read_sql("SELECT * FROM poke_data", engine).to_json(orient='records')
data
# Out:
# '[{"poke_id":1,"poke_name":"Bulbasaur","poke_gen":1,"poke_type1":"grass","poke_type2":"poison","poke_ability1":"Overgrow","poke_ability2":"Chlorophyll","base_total":318,"hp":45,"attack":49,"defense":49,"sp_attack":65,"sp_defense":65,"speed":45,"normal":1.0,"fire":2.0,"water":0.5,"grass":0.25,"electric":0.5,"rock":1.0,"ground":1.0,"flying":2.0,"fighting":0.5,"ice":2.0,"bug":1.0,"steel":1.0,"poison":1.0,"psychic":2.0,"dark":1.0,"ghost":1.0,"fairy":0.5,"dragon":1.0},{"poke_id":2,"poke_name":"Ivysaur","poke_gen":1,"poke_type1":"grass","poke_type2":"poison","poke_ability1":"Overgrow","poke_ability2":"Chlorophyll","base_total":405,"hp":60,"attack":62,"defense":63,"sp_attack":80,"sp_defense":80,"speed":60,"normal":1.0,"fire":2.0,"water":0.5,"grass":0.25,"electric":0.5,"rock":1.0,"ground":1.0,"flying":2.0,"fighting":0.5,"ice":2.0,"bug":1.0,"steel":1.0,"poison":1.0,"psychic":2.0,"dark":1.0,"ghost":1.0,"fairy":0.5,"dragon":1.0},{"poke_id":3,"poke_name":"Venusaur","poke_gen":1,"poke_type1":"grass","poke_type2":"poison","poke_ability1":"Overgrow","poke_ability2":"Chlorophyll","base_total":625,"hp":80,"attack":100,"defense":123,"sp_attack":122,"sp_defense":120,"speed":80,"normal":1.0,"fire":2.0,"water":0.5,"grass":0.25,"electric":0.5,"rock":1.0,"ground":1.0,"flying":2.0,"fighting":0.5,"ice":2.0,"bug":1.0,"steel":1.0,"poison":1.0,"psychic":2.0,"dark":1.0,"ghost":1.0,"fairy":0.5,"dragon":1.0},{"poke_id":4,"poke_name":"Charmander","poke_gen":1,"poke_type1":"fire","poke_type2":"-","poke_ability1":"Blaze","poke_ability2":"Solar Power","base_total":309,"hp":39,"attack":52,"defense":43,"sp_attack":60,"sp_defense":50,"speed":65,"normal":1.0,"fire":0.5,"water":2.0,"grass":0.5,"electric":1.0,"rock":2.0,"ground":2.0,"flying":1.0,"fighting":1.0,"ice":0.5,"bug":0.5,"steel":0.5,"poison":1.0,"psychic":1.0,"dark":1.0,"ghost":1.0,"fairy":0.5,"dragon":1.0},{"poke_id":5,"poke_name":"Charmeleon","poke_gen":1,"poke_type1":"fire","poke_type2":"-","poke_ability1":"Blaze","poke_ability2":"Solar Power","base_total":405,"hp":58,"attack":64,"defense":58,"sp_attack":80,"sp_defense":65,"speed":80,"normal":1.0,"fire":0.5,"water":2.0,"grass":0.5,"electric":1.0,"rock":2.0,"ground":2.0,"flying":1.0,"fighting":1.0,"ice":0.5,"bug":0.5,"steel":0.5,"poison":1.0,"psychic":1.0,"dark":1.0,"ghost":1.0,"fairy":0.5,"dragon":1.0},{"poke_id":6,"poke_name":"Charizard","poke_gen":1,"poke_type1":"fire","poke_type2":"flying","poke_ability1":"Blaze","poke_ability2":"Solar Power","base_total":634,"hp":78,"attack":104,"defense":78,"sp_attack":159,"sp_defense":115,"speed":100,"normal":1.0,"fire":0.5,"water":2.0,"grass":0.25,"electric":2.0,"rock":4.0,"ground":0.0,"flying":1.0,"fighting":0.5,"ice":1.0,"bug":0.25,"steel":0.5,"poison":1.0,"psychic":1.0,"dark":1.0,"ghost":1.0,"fairy":0.5,"dragon":1.0},{"poke_id":7,"poke_name":"Squirtle","poke_gen":1,"poke_type1":"water","poke_type2":"-","poke_ability1":"Torrent","poke_ability2":"Rain Dish","base_total":314,"hp":44,"attack":48,"defense":65,"sp_attack":50,"sp_defense":64,"speed":43,"normal":1.0,"fire":0.5,"water":0.5,"grass":2.0,"electric":2.0,"rock":1.0,"ground":1.0,"flying":1.0,"fighting":1.0,"ice":0.5,"bug":1.0,"steel":0.5,"poison":1.0,"psychic":1.0,"dark":1.0,"ghost":1.0,"fairy":1.0,"dragon":1.0},{"poke_id":8,"poke_name":"Wartortle","poke_gen":1,"poke_type1":"water","poke_type2":"-","poke_ability1":"Torrent","poke_ability2":"Rain Dish","base_total":405,"hp":59,"attack":63,"defense":80,"sp_attack":65,"sp_defense":80,"speed":58,"normal":1.0,"fire":0.5,"water":0.5,"grass":2.0,"electric":2.0,"rock":1.0,"ground":1.0,"flying":1.0,"fighting":1.0,"ice":0.5,"bug":1.0,"steel":0.5,"poison":1.0,"psychic":1.0,"dark":1.0,"ghost":1.0,"fairy":1.0,"dragon":1.0},{"poke_id":9,"poke_name":"Blastoise","poke_gen":1,"poke_type1":"water","poke_type2":"-","poke_ability1":"Torrent","poke_ability2":"Rain Dish","base_total":630,"hp":79,"attack":103,"defense":120,"sp_attack":135,"sp_defense":115,"speed":78,"normal":1.0,"fire":0.5,"water":0.5,"grass":2.0,"electric":2.0,"roc ...

# %%
y = json.loads(data)

# %%
y
# Out:
# [{'poke_id': 1,
#   'poke_name': 'Bulbasaur',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Overgrow',
#   'poke_ability2': 'Chlorophyll',
#   'base_total': 318,
#   'hp': 45,
#   'attack': 49,
#   'defense': 49,
#   'sp_attack': 65,
#   'sp_defense': 65,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 2,
#   'poke_name': 'Ivysaur',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Overgrow',
#   'poke_ability2': 'Chlorophyll',
#   'base_total': 405,
#   'hp': 60,
#   'attack': 62,
#   'defense': 63,
#   'sp_attack': 80,
#   'sp_defense': 80,
#   'speed': 60,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 3,
#   'poke_name': 'Venusaur',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Overgrow',
#   'poke_ability2': 'Chlorophyll',
#   'base_total': 625,
#   'hp': 80,
#   'attack': 100,
#   'defense': 123,
#   'sp_attack': 122,
#   'sp_defense': 120,
#   'speed': 80,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 4,
#   'poke_name': 'Charmander',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': '-',
#   'poke_ability1': 'Blaze',
#   'poke_ability2': 'Solar Power',
#   'base_total': 309,
#   'hp': 39,
#   'attack': 52,
#   'defense': 43,
#   'sp_attack': 60,
#   'sp_defense': 50,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 5,
#   'poke_name': 'Charmeleon',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': '-',
#   'poke_ability1': 'Blaze',
#   'poke_ability2': 'Solar Power',
#   'base_total': 405,
#   'hp': 58,
#   'attack': 64,
#   'defense': 58,
#   'sp_attack': 80,
#   'sp_defense': 65,
#   'speed': 80,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 6,
#   'poke_name': 'Charizard',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Blaze',
#   'poke_ability2': 'Solar Power',
#   'base_total': 634,
#   'hp': 78,
#   'attack': 104,
#   'defense': 78,
#   'sp_attack': 159,
#   'sp_defense': 115,
#   'speed': 100,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.25,
#   'electric': 2.0,
#   'rock': 4.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.25,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 7,
#   'poke_name': 'Squirtle',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Torrent',
#   'poke_ability2': 'Rain Dish',
#   'base_total': 314,
#   'hp': 44,
#   'attack': 48,
#   'defense': 65,
#   'sp_attack': 50,
#   'sp_defense': 64,
#   'speed': 43,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 8,
#   'poke_name': 'Wartortle',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Torrent',
#   'poke_ability2': 'Rain Dish',
#   'base_total': 405,
#   'hp': 59,
#   'attack': 63,
#   'defense': 80,
#   'sp_attack': 65,
#   'sp_defense': 80,
#   'speed': 58,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 9,
#   'poke_name': 'Blastoise',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Torrent',
#   'poke_ability2': 'Rain Dish',
#   'base_total': 630,
#   'hp': 79,
#   'attack': 103,
#   'defense': 120,
#   'sp_attack': 135,
#   'sp_defense': 115,
#   'speed': 78,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 10,
#   'poke_name': 'Caterpie',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': '-',
#   'poke_ability1': 'Shield Dust',
#   'poke_ability2': 'Run Away',
#   'base_total': 195,
#   'hp': 45,
#   'attack': 30,
#   'defense': 35,
#   'sp_attack': 20,
#   'sp_defense': 20,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 0.5,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 11,
#   'poke_name': 'Metapod',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': '-',
#   'poke_ability1': 'Shed Skin',
#   'poke_ability2': '-',
#   'base_total': 205,
#   'hp': 50,
#   'attack': 20,
#   'defense': 55,
#   'sp_attack': 25,
#   'sp_defense': 25,
#   'speed': 30,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 0.5,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 12,
#   'poke_name': 'Butterfree',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Compoundeyes',
#   'poke_ability2': 'Tinted Lens',
#   'base_total': 395,
#   'hp': 60,
#   'attack': 45,
#   'defense': 50,
#   'sp_attack': 90,
#   'sp_defense': 80,
#   'speed': 70,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 2.0,
#   'rock': 4.0,
#   'ground': 0.0,
#   'flying': 2.0,
#   'fighting': 0.25,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 13,
#   'poke_name': 'Weedle',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Shield Dust',
#   'poke_ability2': 'Run Away',
#   'base_total': 195,
#   'hp': 40,
#   'attack': 35,
#   'defense': 30,
#   'sp_attack': 20,
#   'sp_defense': 20,
#   'speed': 50,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.25,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 14,
#   'poke_name': 'Kakuna',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Shed Skin',
#   'poke_ability2': '-',
#   'base_total': 205,
#   'hp': 45,
#   'attack': 25,
#   'defense': 50,
#   'sp_attack': 25,
#   'sp_defense': 25,
#   'speed': 35,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.25,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 15,
#   'poke_name': 'Beedrill',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Swarm',
#   'poke_ability2': 'Sniper',
#   'base_total': 495,
#   'hp': 65,
#   'attack': 150,
#   'defense': 40,
#   'sp_attack': 15,
#   'sp_defense': 80,
#   'speed': 145,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.25,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 16,
#   'poke_name': 'Pidgey',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Keen Eye',
#   'poke_ability2': 'Tangled Feet',
#   'base_total': 251,
#   'hp': 40,
#   'attack': 45,
#   'defense': 40,
#   'sp_attack': 35,
#   'sp_defense': 35,
#   'speed': 56,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 17,
#   'poke_name': 'Pidgeotto',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Keen Eye',
#   'poke_ability2': 'Tangled Feet',
#   'base_total': 349,
#   'hp': 63,
#   'attack': 60,
#   'defense': 55,
#   'sp_attack': 50,
#   'sp_defense': 50,
#   'speed': 71,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 18,
#   'poke_name': 'Pidgeot',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Keen Eye',
#   'poke_ability2': 'Tangled Feet',
#   'base_total': 579,
#   'hp': 83,
#   'attack': 80,
#   'defense': 80,
#   'sp_attack': 135,
#   'sp_defense': 80,
#   'speed': 121,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 19,
#   'poke_name': 'Rattata',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'dark',
#   'poke_ability1': 'Run Away',
#   'poke_ability2': 'Guts',
#   'base_total': 253,
#   'hp': 30,
#   'attack': 56,
#   'defense': 35,
#   'sp_attack': 25,
#   'sp_defense': 35,
#   'speed': 72,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 20,
#   'poke_name': 'Raticate',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'dark',
#   'poke_ability1': 'Run Away',
#   'poke_ability2': 'Guts',
#   'base_total': 413,
#   'hp': 75,
#   'attack': 71,
#   'defense': 70,
#   'sp_attack': 40,
#   'sp_defense': 80,
#   'speed': 77,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 21,
#   'poke_name': 'Spearow',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Keen Eye',
#   'poke_ability2': 'Sniper',
#   'base_total': 262,
#   'hp': 40,
#   'attack': 60,
#   'defense': 30,
#   'sp_attack': 31,
#   'sp_defense': 31,
#   'speed': 70,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 22,
#   'poke_name': 'Fearow',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Keen Eye',
#   'poke_ability2': 'Sniper',
#   'base_total': 442,
#   'hp': 65,
#   'attack': 90,
#   'defense': 65,
#   'sp_attack': 61,
#   'sp_defense': 61,
#   'speed': 100,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 23,
#   'poke_name': 'Ekans',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': '-',
#   'poke_ability1': 'Intimidate',
#   'poke_ability2': 'Shed Skin',
#   'base_total': 288,
#   'hp': 35,
#   'attack': 60,
#   'defense': 44,
#   'sp_attack': 40,
#   'sp_defense': 54,
#   'speed': 55,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 24,
#   'poke_name': 'Arbok',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': '-',
#   'poke_ability1': 'Intimidate',
#   'poke_ability2': 'Shed Skin',
#   'base_total': 448,
#   'hp': 60,
#   'attack': 95,
#   'defense': 69,
#   'sp_attack': 65,
#   'sp_defense': 79,
#   'speed': 80,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 25,
#   'poke_name': 'Pikachu',
#   'poke_gen': 1,
#   'poke_type1': 'electric',
#   'poke_type2': '-',
#   'poke_ability1': 'Static',
#   'poke_ability2': 'Lightningrod',
#   'base_total': 320,
#   'hp': 35,
#   'attack': 55,
#   'defense': 40,
#   'sp_attack': 50,
#   'sp_defense': 50,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 26,
#   'poke_name': 'Raichu',
#   'poke_gen': 1,
#   'poke_type1': 'electric',
#   'poke_type2': 'electric',
#   'poke_ability1': 'Static',
#   'poke_ability2': 'Lightningrod',
#   'base_total': 485,
#   'hp': 60,
#   'attack': 85,
#   'defense': 50,
#   'sp_attack': 95,
#   'sp_defense': 85,
#   'speed': 110,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 27,
#   'poke_name': 'Sandshrew',
#   'poke_gen': 1,
#   'poke_type1': 'ground',
#   'poke_type2': 'ice',
#   'poke_ability1': 'Sand Veil',
#   'poke_ability2': 'Sand Rush',
#   'base_total': 300,
#   'hp': 50,
#   'attack': 75,
#   'defense': 90,
#   'sp_attack': 10,
#   'sp_defense': 35,
#   'speed': 40,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 2.0,
#   'grass': 2.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 28,
#   'poke_name': 'Sandslash',
#   'poke_gen': 1,
#   'poke_type1': 'ground',
#   'poke_type2': 'ice',
#   'poke_ability1': 'Sand Veil',
#   'poke_ability2': 'Sand Rush',
#   'base_total': 450,
#   'hp': 75,
#   'attack': 100,
#   'defense': 120,
#   'sp_attack': 25,
#   'sp_defense': 65,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 2.0,
#   'grass': 2.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 29,
#   'poke_name': 'Nidoranâ\x99\x80',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': '-',
#   'poke_ability1': 'Poison Point',
#   'poke_ability2': 'Rivalry',
#   'base_total': 275,
#   'hp': 55,
#   'attack': 47,
#   'defense': 52,
#   'sp_attack': 40,
#   'sp_defense': 40,
#   'speed': 41,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 30,
#   'poke_name': 'Nidorina',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': '-',
#   'poke_ability1': 'Poison Point',
#   'poke_ability2': 'Rivalry',
#   'base_total': 365,
#   'hp': 70,
#   'attack': 62,
#   'defense': 67,
#   'sp_attack': 55,
#   'sp_defense': 55,
#   'speed': 56,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 31,
#   'poke_name': 'Nidoqueen',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Poison Point',
#   'poke_ability2': 'Rivalry',
#   'base_total': 505,
#   'hp': 90,
#   'attack': 92,
#   'defense': 87,
#   'sp_attack': 75,
#   'sp_defense': 85,
#   'speed': 76,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 2.0,
#   'grass': 1.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.25,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 32,
#   'poke_name': 'Nidoranâ\x99\x82',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': '-',
#   'poke_ability1': 'Poison Point',
#   'poke_ability2': 'Rivalry',
#   'base_total': 273,
#   'hp': 46,
#   'attack': 57,
#   'defense': 40,
#   'sp_attack': 40,
#   'sp_defense': 40,
#   'speed': 50,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 33,
#   'poke_name': 'Nidorino',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': '-',
#   'poke_ability1': 'Poison Point',
#   'poke_ability2': 'Rivalry',
#   'base_total': 365,
#   'hp': 61,
#   'attack': 72,
#   'defense': 57,
#   'sp_attack': 55,
#   'sp_defense': 55,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 34,
#   'poke_name': 'Nidoking',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Poison Point',
#   'poke_ability2': 'Rivalry',
#   'base_total': 505,
#   'hp': 81,
#   'attack': 102,
#   'defense': 77,
#   'sp_attack': 85,
#   'sp_defense': 75,
#   'speed': 85,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 2.0,
#   'grass': 1.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.25,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 35,
#   'poke_name': 'Clefairy',
#   'poke_gen': 1,
#   'poke_type1': 'fairy',
#   'poke_type2': '-',
#   'poke_ability1': 'Cute Charm',
#   'poke_ability2': 'Magic Guard',
#   'base_total': 323,
#   'hp': 70,
#   'attack': 45,
#   'defense': 48,
#   'sp_attack': 60,
#   'sp_defense': 65,
#   'speed': 35,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 2.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 36,
#   'poke_name': 'Clefable',
#   'poke_gen': 1,
#   'poke_type1': 'fairy',
#   'poke_type2': '-',
#   'poke_ability1': 'Cute Charm',
#   'poke_ability2': 'Magic Guard',
#   'base_total': 483,
#   'hp': 95,
#   'attack': 70,
#   'defense': 73,
#   'sp_attack': 95,
#   'sp_defense': 90,
#   'speed': 60,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 2.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 37,
#   'poke_name': 'Vulpix',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': 'ice',
#   'poke_ability1': 'Flash Fire',
#   'poke_ability2': 'Drought',
#   'base_total': 299,
#   'hp': 38,
#   'attack': 41,
#   'defense': 40,
#   'sp_attack': 50,
#   'sp_defense': 65,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 38,
#   'poke_name': 'Ninetales',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': 'ice',
#   'poke_ability1': 'Flash Fire',
#   'poke_ability2': 'Drought',
#   'base_total': 505,
#   'hp': 73,
#   'attack': 67,
#   'defense': 75,
#   'sp_attack': 81,
#   'sp_defense': 100,
#   'speed': 109,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 39,
#   'poke_name': 'Jigglypuff',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Cute Charm',
#   'poke_ability2': 'Competitive',
#   'base_total': 270,
#   'hp': 115,
#   'attack': 45,
#   'defense': 20,
#   'sp_attack': 45,
#   'sp_defense': 25,
#   'speed': 20,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 2.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 40,
#   'poke_name': 'Wigglytuff',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Cute Charm',
#   'poke_ability2': 'Competitive',
#   'base_total': 435,
#   'hp': 140,
#   'attack': 70,
#   'defense': 45,
#   'sp_attack': 85,
#   'sp_defense': 50,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 2.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 41,
#   'poke_name': 'Zubat',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Inner Focus',
#   'poke_ability2': 'Infiltrator',
#   'base_total': 245,
#   'hp': 40,
#   'attack': 45,
#   'defense': 35,
#   'sp_attack': 30,
#   'sp_defense': 40,
#   'speed': 55,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 0.25,
#   'ice': 2.0,
#   'bug': 0.25,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 42,
#   'poke_name': 'Golbat',
#   'poke_gen': 1,
#   'poke_type1': 'poison',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Inner Focus',
#   'poke_ability2': 'Infiltrator',
#   'base_total': 455,
#   'hp': 75,
#   'attack': 80,
#   'defense': 70,
#   'sp_attack': 65,
#   'sp_defense': 75,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 2.0,
#   'rock': 2.0,
#   'ground': 0.0,
#   'flying': 1.0,
#   'fighting': 0.25,
#   'ice': 2.0,
#   'bug': 0.25,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 43,
#   'poke_name': 'Oddish',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Chlorophyll',
#   'poke_ability2': 'Run Away',
#   'base_total': 320,
#   'hp': 45,
#   'attack': 50,
#   'defense': 55,
#   'sp_attack': 75,
#   'sp_defense': 65,
#   'speed': 30,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 44,
#   'poke_name': 'Gloom',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Chlorophyll',
#   'poke_ability2': 'Stench',
#   'base_total': 395,
#   'hp': 60,
#   'attack': 65,
#   'defense': 70,
#   'sp_attack': 85,
#   'sp_defense': 75,
#   'speed': 40,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 45,
#   'poke_name': 'Vileplume',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Chlorophyll',
#   'poke_ability2': 'Effect Spore',
#   'base_total': 490,
#   'hp': 75,
#   'attack': 80,
#   'defense': 85,
#   'sp_attack': 110,
#   'sp_defense': 90,
#   'speed': 50,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 46,
#   'poke_name': 'Paras',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'grass',
#   'poke_ability1': 'Effect Spore',
#   'poke_ability2': 'Dry Skin',
#   'base_total': 285,
#   'hp': 35,
#   'attack': 70,
#   'defense': 55,
#   'sp_attack': 45,
#   'sp_defense': 55,
#   'speed': 25,
#   'normal': 1.0,
#   'fire': 4.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 2.0,
#   'ground': 0.25,
#   'flying': 4.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 47,
#   'poke_name': 'Parasect',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'grass',
#   'poke_ability1': 'Effect Spore',
#   'poke_ability2': 'Dry Skin',
#   'base_total': 405,
#   'hp': 60,
#   'attack': 95,
#   'defense': 80,
#   'sp_attack': 60,
#   'sp_defense': 80,
#   'speed': 30,
#   'normal': 1.0,
#   'fire': 4.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 2.0,
#   'ground': 0.25,
#   'flying': 4.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 48,
#   'poke_name': 'Venonat',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Compoundeyes',
#   'poke_ability2': 'Tinted Lens',
#   'base_total': 305,
#   'hp': 60,
#   'attack': 55,
#   'defense': 50,
#   'sp_attack': 40,
#   'sp_defense': 55,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.25,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 49,
#   'poke_name': 'Venomoth',
#   'poke_gen': 1,
#   'poke_type1': 'bug',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Shield Dust',
#   'poke_ability2': 'Tinted Lens',
#   'base_total': 450,
#   'hp': 70,
#   'attack': 65,
#   'defense': 60,
#   'sp_attack': 90,
#   'sp_defense': 75,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.25,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 50,
#   'poke_name': 'Diglett',
#   'poke_gen': 1,
#   'poke_type1': 'ground',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Sand Veil',
#   'poke_ability2': 'Arena Trap',
#   'base_total': 265,
#   'hp': 10,
#   'attack': 55,
#   'defense': 30,
#   'sp_attack': 35,
#   'sp_defense': 45,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 2.0,
#   'grass': 2.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 51,
#   'poke_name': 'Dugtrio',
#   'poke_gen': 1,
#   'poke_type1': 'ground',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Sand Veil',
#   'poke_ability2': 'Arena Trap',
#   'base_total': 425,
#   'hp': 35,
#   'attack': 100,
#   'defense': 60,
#   'sp_attack': 50,
#   'sp_defense': 70,
#   'speed': 110,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 2.0,
#   'grass': 2.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 52,
#   'poke_name': 'Meowth',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'dark',
#   'poke_ability1': 'Pickup',
#   'poke_ability2': 'Technician',
#   'base_total': 290,
#   'hp': 40,
#   'attack': 35,
#   'defense': 35,
#   'sp_attack': 50,
#   'sp_defense': 40,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 53,
#   'poke_name': 'Persian',
#   'poke_gen': 1,
#   'poke_type1': 'normal',
#   'poke_type2': 'dark',
#   'poke_ability1': 'Limber',
#   'poke_ability2': 'Technician',
#   'base_total': 440,
#   'hp': 65,
#   'attack': 60,
#   'defense': 60,
#   'sp_attack': 75,
#   'sp_defense': 65,
#   'speed': 115,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 54,
#   'poke_name': 'Psyduck',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Damp',
#   'poke_ability2': 'Cloud Nine',
#   'base_total': 320,
#   'hp': 50,
#   'attack': 52,
#   'defense': 48,
#   'sp_attack': 65,
#   'sp_defense': 50,
#   'speed': 55,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 55,
#   'poke_name': 'Golduck',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Damp',
#   'poke_ability2': 'Cloud Nine',
#   'base_total': 500,
#   'hp': 80,
#   'attack': 82,
#   'defense': 78,
#   'sp_attack': 95,
#   'sp_defense': 80,
#   'speed': 85,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 56,
#   'poke_name': 'Mankey',
#   'poke_gen': 1,
#   'poke_type1': 'fighting',
#   'poke_type2': '-',
#   'poke_ability1': 'Vital Spirit',
#   'poke_ability2': 'Anger Point',
#   'base_total': 305,
#   'hp': 40,
#   'attack': 80,
#   'defense': 35,
#   'sp_attack': 35,
#   'sp_defense': 45,
#   'speed': 70,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 57,
#   'poke_name': 'Primeape',
#   'poke_gen': 1,
#   'poke_type1': 'fighting',
#   'poke_type2': '-',
#   'poke_ability1': 'Vital Spirit',
#   'poke_ability2': 'Anger Point',
#   'base_total': 455,
#   'hp': 65,
#   'attack': 105,
#   'defense': 60,
#   'sp_attack': 60,
#   'sp_defense': 70,
#   'speed': 95,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 58,
#   'poke_name': 'Growlithe',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': '-',
#   'poke_ability1': 'Intimidate',
#   'poke_ability2': 'Flash Fire',
#   'base_total': 350,
#   'hp': 55,
#   'attack': 70,
#   'defense': 45,
#   'sp_attack': 70,
#   'sp_defense': 50,
#   'speed': 60,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 59,
#   'poke_name': 'Arcanine',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': '-',
#   'poke_ability1': 'Intimidate',
#   'poke_ability2': 'Flash Fire',
#   'base_total': 555,
#   'hp': 90,
#   'attack': 110,
#   'defense': 80,
#   'sp_attack': 100,
#   'sp_defense': 80,
#   'speed': 95,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 60,
#   'poke_name': 'Poliwag',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Water Absorb',
#   'poke_ability2': 'Damp',
#   'base_total': 300,
#   'hp': 40,
#   'attack': 50,
#   'defense': 40,
#   'sp_attack': 40,
#   'sp_defense': 40,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 61,
#   'poke_name': 'Poliwhirl',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': '-',
#   'poke_ability1': 'Water Absorb',
#   'poke_ability2': 'Damp',
#   'base_total': 385,
#   'hp': 65,
#   'attack': 65,
#   'defense': 65,
#   'sp_attack': 50,
#   'sp_defense': 50,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 62,
#   'poke_name': 'Poliwrath',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': 'fighting',
#   'poke_ability1': 'Water Absorb',
#   'poke_ability2': 'Damp',
#   'base_total': 510,
#   'hp': 90,
#   'attack': 95,
#   'defense': 95,
#   'sp_attack': 70,
#   'sp_defense': 90,
#   'speed': 70,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 63,
#   'poke_name': 'Abra',
#   'poke_gen': 1,
#   'poke_type1': 'psychic',
#   'poke_type2': '-',
#   'poke_ability1': 'Synchronize',
#   'poke_ability2': 'Inner Focus',
#   'base_total': 310,
#   'hp': 25,
#   'attack': 20,
#   'defense': 15,
#   'sp_attack': 105,
#   'sp_defense': 55,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 64,
#   'poke_name': 'Kadabra',
#   'poke_gen': 1,
#   'poke_type1': 'psychic',
#   'poke_type2': '-',
#   'poke_ability1': 'Synchronize',
#   'poke_ability2': 'Inner Focus',
#   'base_total': 400,
#   'hp': 40,
#   'attack': 35,
#   'defense': 30,
#   'sp_attack': 120,
#   'sp_defense': 70,
#   'speed': 105,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 65,
#   'poke_name': 'Alakazam',
#   'poke_gen': 1,
#   'poke_type1': 'psychic',
#   'poke_type2': '-',
#   'poke_ability1': 'Synchronize',
#   'poke_ability2': 'Inner Focus',
#   'base_total': 600,
#   'hp': 55,
#   'attack': 50,
#   'defense': 65,
#   'sp_attack': 175,
#   'sp_defense': 105,
#   'speed': 150,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 66,
#   'poke_name': 'Machop',
#   'poke_gen': 1,
#   'poke_type1': 'fighting',
#   'poke_type2': '-',
#   'poke_ability1': 'Guts',
#   'poke_ability2': 'No Guard',
#   'base_total': 305,
#   'hp': 70,
#   'attack': 80,
#   'defense': 50,
#   'sp_attack': 35,
#   'sp_defense': 35,
#   'speed': 35,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 67,
#   'poke_name': 'Machoke',
#   'poke_gen': 1,
#   'poke_type1': 'fighting',
#   'poke_type2': '-',
#   'poke_ability1': 'Guts',
#   'poke_ability2': 'No Guard',
#   'base_total': 405,
#   'hp': 80,
#   'attack': 100,
#   'defense': 70,
#   'sp_attack': 50,
#   'sp_defense': 60,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 68,
#   'poke_name': 'Machamp',
#   'poke_gen': 1,
#   'poke_type1': 'fighting',
#   'poke_type2': '-',
#   'poke_ability1': 'Guts',
#   'poke_ability2': 'No Guard',
#   'base_total': 505,
#   'hp': 90,
#   'attack': 130,
#   'defense': 80,
#   'sp_attack': 65,
#   'sp_defense': 85,
#   'speed': 55,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 69,
#   'poke_name': 'Bellsprout',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Chlorophyll',
#   'poke_ability2': 'Gluttony',
#   'base_total': 300,
#   'hp': 50,
#   'attack': 75,
#   'defense': 35,
#   'sp_attack': 70,
#   'sp_defense': 30,
#   'speed': 40,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 70,
#   'poke_name': 'Weepinbell',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Chlorophyll',
#   'poke_ability2': 'Gluttony',
#   'base_total': 390,
#   'hp': 65,
#   'attack': 90,
#   'defense': 50,
#   'sp_attack': 85,
#   'sp_defense': 45,
#   'speed': 55,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 71,
#   'poke_name': 'Victreebel',
#   'poke_gen': 1,
#   'poke_type1': 'grass',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Chlorophyll',
#   'poke_ability2': 'Gluttony',
#   'base_total': 490,
#   'hp': 80,
#   'attack': 105,
#   'defense': 65,
#   'sp_attack': 100,
#   'sp_defense': 70,
#   'speed': 70,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 72,
#   'poke_name': 'Tentacool',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Clear Body',
#   'poke_ability2': 'Liquid Ooze',
#   'base_total': 335,
#   'hp': 40,
#   'attack': 40,
#   'defense': 35,
#   'sp_attack': 50,
#   'sp_defense': 100,
#   'speed': 70,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 1.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 73,
#   'poke_name': 'Tentacruel',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Clear Body',
#   'poke_ability2': 'Liquid Ooze',
#   'base_total': 515,
#   'hp': 80,
#   'attack': 70,
#   'defense': 65,
#   'sp_attack': 80,
#   'sp_defense': 120,
#   'speed': 100,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 1.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 0.5,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 74,
#   'poke_name': 'Geodude',
#   'poke_gen': 1,
#   'poke_type1': 'rock',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Rock Head',
#   'poke_ability2': 'Sturdy',
#   'base_total': 300,
#   'hp': 40,
#   'attack': 80,
#   'defense': 100,
#   'sp_attack': 30,
#   'sp_defense': 30,
#   'speed': 20,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 4.0,
#   'grass': 4.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 2.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 2.0,
#   'poison': 0.25,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 75,
#   'poke_name': 'Graveler',
#   'poke_gen': 1,
#   'poke_type1': 'rock',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Rock Head',
#   'poke_ability2': 'Sturdy',
#   'base_total': 390,
#   'hp': 55,
#   'attack': 95,
#   'defense': 115,
#   'sp_attack': 45,
#   'sp_defense': 45,
#   'speed': 35,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 4.0,
#   'grass': 4.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 2.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 2.0,
#   'poison': 0.25,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 76,
#   'poke_name': 'Golem',
#   'poke_gen': 1,
#   'poke_type1': 'rock',
#   'poke_type2': 'ground',
#   'poke_ability1': 'Rock Head',
#   'poke_ability2': 'Sturdy',
#   'base_total': 495,
#   'hp': 80,
#   'attack': 120,
#   'defense': 130,
#   'sp_attack': 55,
#   'sp_defense': 65,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 4.0,
#   'grass': 4.0,
#   'electric': 0.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 2.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 2.0,
#   'poison': 0.25,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 77,
#   'poke_name': 'Ponyta',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': '-',
#   'poke_ability1': 'Run Away',
#   'poke_ability2': 'Flash Fire',
#   'base_total': 410,
#   'hp': 50,
#   'attack': 85,
#   'defense': 55,
#   'sp_attack': 65,
#   'sp_defense': 65,
#   'speed': 90,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 78,
#   'poke_name': 'Rapidash',
#   'poke_gen': 1,
#   'poke_type1': 'fire',
#   'poke_type2': '-',
#   'poke_ability1': 'Run Away',
#   'poke_ability2': 'Flash Fire',
#   'base_total': 500,
#   'hp': 65,
#   'attack': 100,
#   'defense': 70,
#   'sp_attack': 80,
#   'sp_defense': 80,
#   'speed': 105,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 79,
#   'poke_name': 'Slowpoke',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': 'psychic',
#   'poke_ability1': 'Oblivious',
#   'poke_ability2': 'Own Tempo',
#   'base_total': 315,
#   'hp': 90,
#   'attack': 65,
#   'defense': 65,
#   'sp_attack': 40,
#   'sp_defense': 40,
#   'speed': 15,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 0.5,
#   'bug': 2.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 80,
#   'poke_name': 'Slowbro',
#   'poke_gen': 1,
#   'poke_type1': 'water',
#   'poke_type2': 'psychic',
#   'poke_ability1': 'Oblivious',
#   'poke_ability2': 'Own Tempo',
#   'base_total': 590,
#   'hp': 95,
#   'attack': 75,
#   'defense': 180,
#   'sp_attack': 130,
#   'sp_defense': 80,
#   'speed': 30,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 0.5,
#   'bug': 2.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 81,
#   'poke_name': 'Magnemite',
#   'poke_gen': 1,
#   'poke_type1': 'electric',
#   'poke_type2': 'steel',
#   'poke_ability1': 'Magnet Pull',
#   'poke_ability2': 'Sturdy',
#   'base_total': 325,
#   'hp': 25,
#   'attack': 35,
#   'defense': 70,
#   'sp_attack': 95,
#   'sp_defense': 55,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 0.5,
#   'ground': 4.0,
#   'flying': 0.25,
#   'fighting': 2.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.25,
#   'poison': 0.0,
#   'psychic': 0.5,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 0.5},
#  {'poke_id': 82,
#   'poke_name': 'Magneton',
#   'poke_gen': 1,
#   'poke_type1': 'electric',
#   'poke_type2': 'steel',
#   'poke_ability1': 'Magnet Pull',
#   'poke_ability2': 'Sturdy',
#   'base_total': 465,
#   'hp': 50,
# ...
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 775,
#   'poke_name': 'Komala',
#   'poke_gen': 7,
#   'poke_type1': 'normal',
#   'poke_type2': '-',
#   'poke_ability1': 'Comatose',
#   'poke_ability2': '-',
#   'base_total': 480,
#   'hp': 65,
#   'attack': 115,
#   'defense': 65,
#   'sp_attack': 75,
#   'sp_defense': 95,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 776,
#   'poke_name': 'Turtonator',
#   'poke_gen': 7,
#   'poke_type1': 'fire',
#   'poke_type2': 'dragon',
#   'poke_ability1': 'Shell Armor',
#   'poke_ability2': '-',
#   'base_total': 485,
#   'hp': 60,
#   'attack': 78,
#   'defense': 135,
#   'sp_attack': 91,
#   'sp_defense': 85,
#   'speed': 36,
#   'normal': 1.0,
#   'fire': 0.25,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 2.0,
#   'ground': 2.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 2.0},
#  {'poke_id': 777,
#   'poke_name': 'Togedemaru',
#   'poke_gen': 7,
#   'poke_type1': 'electric',
#   'poke_type2': 'steel',
#   'poke_ability1': 'Iron Barbs',
#   'poke_ability2': 'Lightningrod',
#   'base_total': 435,
#   'hp': 65,
#   'attack': 98,
#   'defense': 63,
#   'sp_attack': 40,
#   'sp_defense': 73,
#   'speed': 96,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 0.5,
#   'ground': 4.0,
#   'flying': 0.25,
#   'fighting': 2.0,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 0.25,
#   'poison': 0.0,
#   'psychic': 0.5,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 0.5},
#  {'poke_id': 778,
#   'poke_name': 'Mimikyu',
#   'poke_gen': 7,
#   'poke_type1': 'ghost',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Disguise',
#   'poke_ability2': '-',
#   'base_total': 476,
#   'hp': 55,
#   'attack': 90,
#   'defense': 80,
#   'sp_attack': 50,
#   'sp_defense': 105,
#   'speed': 96,
#   'normal': 0.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.0,
#   'ice': 1.0,
#   'bug': 0.25,
#   'steel': 2.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 779,
#   'poke_name': 'Bruxish',
#   'poke_gen': 7,
#   'poke_type1': 'water',
#   'poke_type2': 'psychic',
#   'poke_ability1': 'Dazzling',
#   'poke_ability2': 'Strong Jaw',
#   'base_total': 475,
#   'hp': 68,
#   'attack': 105,
#   'defense': 70,
#   'sp_attack': 70,
#   'sp_defense': 70,
#   'speed': 92,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 0.5,
#   'bug': 2.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 780,
#   'poke_name': 'Drampa',
#   'poke_gen': 7,
#   'poke_type1': 'normal',
#   'poke_type2': 'dragon',
#   'poke_ability1': 'Berserk',
#   'poke_ability2': 'Sap Sipper',
#   'base_total': 485,
#   'hp': 78,
#   'attack': 60,
#   'defense': 85,
#   'sp_attack': 135,
#   'sp_defense': 91,
#   'speed': 36,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 0.0,
#   'fairy': 2.0,
#   'dragon': 2.0},
#  {'poke_id': 781,
#   'poke_name': 'Dhelmise',
#   'poke_gen': 7,
#   'poke_type1': 'ghost',
#   'poke_type2': 'grass',
#   'poke_ability1': 'Steelworker',
#   'poke_ability2': '-',
#   'base_total': 517,
#   'hp': 70,
#   'attack': 131,
#   'defense': 100,
#   'sp_attack': 86,
#   'sp_defense': 90,
#   'speed': 40,
#   'normal': 0.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 0.5,
#   'flying': 2.0,
#   'fighting': 0.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 782,
#   'poke_name': 'Jangmo-o',
#   'poke_gen': 7,
#   'poke_type1': 'dragon',
#   'poke_type2': '-',
#   'poke_ability1': 'Bulletproof',
#   'poke_ability2': 'Soundproof',
#   'base_total': 300,
#   'hp': 45,
#   'attack': 55,
#   'defense': 65,
#   'sp_attack': 45,
#   'sp_defense': 45,
#   'speed': 45,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 2.0},
#  {'poke_id': 783,
#   'poke_name': 'Hakamo-o',
#   'poke_gen': 7,
#   'poke_type1': 'dragon',
#   'poke_type2': 'fighting',
#   'poke_ability1': 'Bulletproof',
#   'poke_ability2': 'Soundproof',
#   'base_total': 420,
#   'hp': 55,
#   'attack': 75,
#   'defense': 90,
#   'sp_attack': 65,
#   'sp_defense': 70,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 4.0,
#   'dragon': 2.0},
#  {'poke_id': 784,
#   'poke_name': 'Kommo-o',
#   'poke_gen': 7,
#   'poke_type1': 'dragon',
#   'poke_type2': 'fighting',
#   'poke_ability1': 'Bulletproof',
#   'poke_ability2': 'Soundproof',
#   'base_total': 600,
#   'hp': 75,
#   'attack': 110,
#   'defense': 125,
#   'sp_attack': 100,
#   'sp_defense': 105,
#   'speed': 85,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 2.0,
#   'fighting': 1.0,
#   'ice': 2.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 4.0,
#   'dragon': 2.0},
#  {'poke_id': 785,
#   'poke_name': 'Tapu Koko',
#   'poke_gen': 7,
#   'poke_type1': 'electric',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Electric Surge',
#   'poke_ability2': 'Telepathy',
#   'base_total': 570,
#   'hp': 70,
#   'attack': 115,
#   'defense': 85,
#   'sp_attack': 95,
#   'sp_defense': 75,
#   'speed': 130,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 786,
#   'poke_name': 'Tapu Lele',
#   'poke_gen': 7,
#   'poke_type1': 'psychic',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Psychic Surge',
#   'poke_ability2': 'Telepathy',
#   'base_total': 570,
#   'hp': 70,
#   'attack': 85,
#   'defense': 75,
#   'sp_attack': 130,
#   'sp_defense': 115,
#   'speed': 95,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.25,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 2.0,
#   'poison': 2.0,
#   'psychic': 0.5,
#   'dark': 1.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 787,
#   'poke_name': 'Tapu Bulu',
#   'poke_gen': 7,
#   'poke_type1': 'grass',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Grassy Surge',
#   'poke_ability2': 'Telepathy',
#   'base_total': 570,
#   'hp': 70,
#   'attack': 130,
#   'defense': 115,
#   'sp_attack': 85,
#   'sp_defense': 95,
#   'speed': 75,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 0.5,
#   'flying': 2.0,
#   'fighting': 0.5,
#   'ice': 2.0,
#   'bug': 1.0,
#   'steel': 2.0,
#   'poison': 4.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 788,
#   'poke_name': 'Tapu Fini',
#   'poke_gen': 7,
#   'poke_type1': 'water',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Misty Surge',
#   'poke_ability2': 'Telepathy',
#   'base_total': 570,
#   'hp': 70,
#   'attack': 75,
#   'defense': 115,
#   'sp_attack': 95,
#   'sp_defense': 130,
#   'speed': 85,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 2.0,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 0.5,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 0.0},
#  {'poke_id': 789,
#   'poke_name': 'Cosmog',
#   'poke_gen': 7,
#   'poke_type1': 'psychic',
#   'poke_type2': '-',
#   'poke_ability1': 'Unaware',
#   'poke_ability2': '-',
#   'base_total': 200,
#   'hp': 43,
#   'attack': 29,
#   'defense': 31,
#   'sp_attack': 29,
#   'sp_defense': 31,
#   'speed': 37,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 790,
#   'poke_name': 'Cosmoem',
#   'poke_gen': 7,
#   'poke_type1': 'psychic',
#   'poke_type2': '-',
#   'poke_ability1': 'Sturdy',
#   'poke_ability2': '-',
#   'base_total': 400,
#   'hp': 43,
#   'attack': 29,
#   'defense': 131,
#   'sp_attack': 29,
#   'sp_defense': 131,
#   'speed': 37,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 791,
#   'poke_name': 'Solgaleo',
#   'poke_gen': 7,
#   'poke_type1': 'psychic',
#   'poke_type2': 'steel',
#   'poke_ability1': 'Full Metal Body',
#   'poke_ability2': '-',
#   'base_total': 680,
#   'hp': 137,
#   'attack': 137,
#   'defense': 107,
#   'sp_attack': 113,
#   'sp_defense': 89,
#   'speed': 97,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 0.0,
#   'psychic': 0.25,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 0.5,
#   'dragon': 0.5},
#  {'poke_id': 792,
#   'poke_name': 'Lunala',
#   'poke_gen': 7,
#   'poke_type1': 'psychic',
#   'poke_type2': 'ghost',
#   'poke_ability1': 'Shadow Shield',
#   'poke_ability2': '-',
#   'base_total': 680,
#   'hp': 137,
#   'attack': 113,
#   'defense': 89,
#   'sp_attack': 137,
#   'sp_defense': 107,
#   'speed': 97,
#   'normal': 0.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 1.0,
#   'poison': 0.5,
#   'psychic': 0.5,
#   'dark': 4.0,
#   'ghost': 4.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 793,
#   'poke_name': 'Nihilego',
#   'poke_gen': 7,
#   'poke_type1': 'rock',
#   'poke_type2': 'poison',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 109,
#   'attack': 53,
#   'defense': 47,
#   'sp_attack': 127,
#   'sp_defense': 131,
#   'speed': 103,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 2.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 4.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 2.0,
#   'poison': 0.25,
#   'psychic': 2.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 1.0},
#  {'poke_id': 794,
#   'poke_name': 'Buzzwole',
#   'poke_gen': 7,
#   'poke_type1': 'bug',
#   'poke_type2': 'fighting',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 107,
#   'attack': 139,
#   'defense': 139,
#   'sp_attack': 53,
#   'sp_defense': 53,
#   'speed': 79,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 0.5,
#   'flying': 4.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 795,
#   'poke_name': 'Pheromosa',
#   'poke_gen': 7,
#   'poke_type1': 'bug',
#   'poke_type2': 'fighting',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 71,
#   'attack': 137,
#   'defense': 37,
#   'sp_attack': 137,
#   'sp_defense': 37,
#   'speed': 151,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 0.5,
#   'flying': 4.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 0.5,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 2.0,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 2.0,
#   'dragon': 1.0},
#  {'poke_id': 796,
#   'poke_name': 'Xurkitree',
#   'poke_gen': 7,
#   'poke_type1': 'electric',
#   'poke_type2': '-',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 83,
#   'attack': 89,
#   'defense': 71,
#   'sp_attack': 173,
#   'sp_defense': 71,
#   'speed': 83,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 1.0,
#   'psychic': 1.0,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 797,
#   'poke_name': 'Celesteela',
#   'poke_gen': 7,
#   'poke_type1': 'steel',
#   'poke_type2': 'flying',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 97,
#   'attack': 101,
#   'defense': 103,
#   'sp_attack': 107,
#   'sp_defense': 101,
#   'speed': 61,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.25,
#   'electric': 2.0,
#   'rock': 1.0,
#   'ground': 0.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 1.0,
#   'bug': 0.25,
#   'steel': 0.5,
#   'poison': 0.0,
#   'psychic': 0.5,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 0.5},
#  {'poke_id': 798,
#   'poke_name': 'Kartana',
#   'poke_gen': 7,
#   'poke_type1': 'grass',
#   'poke_type2': 'steel',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 59,
#   'attack': 181,
#   'defense': 131,
#   'sp_attack': 59,
#   'sp_defense': 31,
#   'speed': 109,
#   'normal': 1.0,
#   'fire': 4.0,
#   'water': 0.5,
#   'grass': 0.25,
#   'electric': 0.5,
#   'rock': 0.5,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 1.0,
#   'bug': 1.0,
#   'steel': 0.5,
#   'poison': 0.0,
#   'psychic': 0.5,
#   'dark': 1.0,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 0.5},
#  {'poke_id': 799,
#   'poke_name': 'Guzzlord',
#   'poke_gen': 7,
#   'poke_type1': 'dark',
#   'poke_type2': 'dragon',
#   'poke_ability1': 'Beast Boost',
#   'poke_ability2': '-',
#   'base_total': 570,
#   'hp': 223,
#   'attack': 101,
#   'defense': 53,
#   'sp_attack': 97,
#   'sp_defense': 53,
#   'speed': 43,
#   'normal': 1.0,
#   'fire': 0.5,
#   'water': 0.5,
#   'grass': 0.5,
#   'electric': 0.5,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 2.0,
#   'ice': 2.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.0,
#   'dark': 0.5,
#   'ghost': 0.5,
#   'fairy': 4.0,
#   'dragon': 2.0},
#  {'poke_id': 800,
#   'poke_name': 'Necrozma',
#   'poke_gen': 7,
#   'poke_type1': 'psychic',
#   'poke_type2': '-',
#   'poke_ability1': 'Prism Armor',
#   'poke_ability2': '-',
#   'base_total': 600,
#   'hp': 97,
#   'attack': 107,
#   'defense': 101,
#   'sp_attack': 127,
#   'sp_defense': 89,
#   'speed': 79,
#   'normal': 1.0,
#   'fire': 1.0,
#   'water': 1.0,
#   'grass': 1.0,
#   'electric': 1.0,
#   'rock': 1.0,
#   'ground': 1.0,
#   'flying': 1.0,
#   'fighting': 0.5,
#   'ice': 1.0,
#   'bug': 2.0,
#   'steel': 1.0,
#   'poison': 1.0,
#   'psychic': 0.5,
#   'dark': 2.0,
#   'ghost': 2.0,
#   'fairy': 1.0,
#   'dragon': 1.0},
#  {'poke_id': 801,
#   'poke_name': 'Magearna',
#   'poke_gen': 7,
#   'poke_type1': 'steel',
#   'poke_type2': 'fairy',
#   'poke_ability1': 'Soul-Heart',
#   'poke_ability2': '-',
#   'base_total': 600,
#   'hp': 80,
#   'attack': 95,
#   'defense': 115,
#   'sp_attack': 130,
#   'sp_defense': 115,
#   'speed': 65,
#   'normal': 1.0,
#   'fire': 2.0,
#   'water': 1.0,
#   'grass': 0.5,
#   'electric': 1.0,
#   'rock': 0.5,
#   'ground': 2.0,
#   'flying': 0.5,
#   'fighting': 1.0,
#   'ice': 0.5,
#   'bug': 0.25,
#   'steel': 1.0,
#   'poison': 0.0,
#   'psychic': 0.5,
#   'dark': 0.5,
#   'ghost': 1.0,
#   'fairy': 0.5,
#   'dragon': 0.0}]

# %%
type(y)
# Out:
# list
